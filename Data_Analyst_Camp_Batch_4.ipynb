# %% [markdown]
# # Data Analyst Camp Batch 4
#
# Main : Memahami struktur dan kualitas data peserta magang
#
# Task :
# 1. Melakukan eksplorasi awal terhadap data pendaftaran internship.
# 2. Menangani data kosong secara logis (imputasi), mengidentifikasi dan memperbaiki data yang duplikat, kosong, atau tidak konsisten.
# 3. Menghitung statistik deskriptif (total peserta, jenis kelamin, asal provinsi, perguruan tinggi, departemen yang diminati).
# 4. Menghitung metrik unik: "Rasio Pria vs Wanita per Departemen".

# %% [markdown]
# # Library

# %%
import io
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import files

# %%
# Upload data
uploaded = files.upload()
# Out:
#      <input type="file" id="files-aec5b133-9e94-4d42-acbb-b3022b0734e6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-aec5b133-9e94-4d42-acbb-b3022b0734e6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = pd.read_csv(io.BytesIO(uploaded['Form Pendaftaran Internship (Jawaban).xlsx - Form Responses 1.csv']))

# %% [markdown]
# #EDA

# %%
#menampilkan 5 data pertama
data.head()
# Out:
#             Timestamp    Nama Lengkap Jenis Kelamin  \
# 0   1/23/2022 7:50:59  Aditya Pratama     Perempuan
# 1   1/23/2022 8:55:30  Siti Nurhaliza     Perempuan
# 2   1/23/2022 9:05:02   Rizky Maulana     Perempuan
# 3   1/23/2022 9:34:07     Dwi Lestari     Perempuan
# 4  1/23/2022 12:02:46    Bayu Saputra     Perempuan
#
#                 Asal Perguruan Tinggi    Asal Provinsi  \
# 0              Universitas Padjadjaran          Banten
# 1  Universitas Singaperbangsa Karawang      Jawa Barat
# 2           Universitas Sumatera Utara  Sumatera Utara
# 3            Politeknik Negeri Jakarta      Jawa Barat
# 4                Universitas Brawijaya      Jawa Timur
#
#   Departemen apa yang kamu inginkan?  \
# 0         Administration and Finance
# 1         Administration and Finance
# 2         Administration and Finance
# 3         Administration and Finance
# 4         Administration and Finance
#
#     Apa alasan kamu menginginkan departemen tersebut  \
# ...

# %% [markdown]
# Miss Value, Duplicated Data Handle

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463 entries, 0 to 462
# Data columns (total 10 columns):
#  #   Column                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                   --------------  -----
#  0   Timestamp                                                                                463 non-null    object
#  1   Nama Lengkap                                                                             463 non-null    object
#  2   Jenis Kelamin                                                                            463 non-null    object
#  3   Asal Perguruan Tinggi                                                                    463 non-null    object
#  4   Asal Provinsi                                                                            463 non-null    object
# ...

# %%
data.isna().sum()
# Out:
# Timestamp                                                                                  0
# Nama Lengkap                                                                               0
# Jenis Kelamin                                                                              0
# Asal Perguruan Tinggi                                                                      0
# Asal Provinsi                                                                              0
# Departemen apa yang kamu inginkan?                                                         0
# Apa alasan kamu menginginkan departemen tersebut                                           0
# Skill apa yang kamu miliki saat ini?                                                       0
# Skill apa yang sedang kamu pelajari saat ini?                                              0
# apakah kamu bersedia untuk melakuan Internship Program di Ousean Group selama 3 bulan?     0
# dtype: int64

# %% [markdown]
# Terlihat tidak ada data hilang. data berjumlah sebanyak 463 data

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Terlihat tidak ada duplikasi data

# %% [markdown]
# Descriptive Statistic

# %%
data.describe()
# Out:
#                Timestamp  Nama Lengkap Jenis Kelamin  Asal Perguruan Tinggi   \
# count                463           463           463                     463
# unique               463           460             2                     225
# top     2/7/2022 5:21:27  Yuliana Sari     Perempuan  Universitas Diponegoro
# freq                   1             2           338                      26
#
#        Asal Provinsi Departemen apa yang kamu inginkan?  \
# count            463                                463
# unique            26                                  9
# top       Jawa Barat         Administration and Finance
# freq             101                                123
#
#          Apa alasan kamu menginginkan departemen tersebut  \
# count                                                 463
# unique                                                463
# top     Saya memiliki pengalaman dan kompetensi dalam ...
# freq                                                    1
#
# ...

# %% [markdown]
# 1. Total Peserta

# %%
data.count()
# Out:
# Timestamp                                                                                  463
# Nama Lengkap                                                                               463
# Jenis Kelamin                                                                              463
# Asal Perguruan Tinggi                                                                      463
# Asal Provinsi                                                                              463
# Departemen apa yang kamu inginkan?                                                         463
# Apa alasan kamu menginginkan departemen tersebut                                           463
# Skill apa yang kamu miliki saat ini?                                                       463
# Skill apa yang sedang kamu pelajari saat ini?                                              463
# apakah kamu bersedia untuk melakuan Internship Program di Ousean Group selama 3 bulan?     463
# dtype: int64

# %% [markdown]
# Terdapat 463 data peserta

# %% [markdown]
# 2. Jenis Kelamin

# %%
plt.figure()
plt.title('Jenis Kelamin')
sns.countplot(x='Jenis Kelamin', data=data)
# Out:
# <Axes: title={'center': 'Jenis'}, xlabel='Jenis Kelamin', ylabel='count'>

# %%
data['Jenis Kelamin'].value_counts()
# Out:
# Jenis Kelamin
# Perempuan    338
# Laki-laki    125
# Name: count, dtype: int64

# %% [markdown]
# Perempuan berjumlah 338 peserta dan laki-laki berjumlah 125 peserta

# %% [markdown]
# 3. Asal Provinsi

# %%
data['Asal Provinsi'].value_counts()
# Out:
# Asal Provinsi
# Jawa Barat                     101
# Jawa Timur                      91
# Jawa Tengah                     68
# DKI Jakarta                     56
# Banten                          55
# Sumatera Utara                  23
# DI Yogyakarta                   12
# Sumatera Barat                   9
# Sulawesi Selatan                 7
# Sumatera Selatan                 5
# Riau                             4
# Bali                             4
# Lampung                          4
# Aceh                             3
# Kalimantan Barat                 3
# Nusa Tenggara Timur              3
# Kalimantan Timur                 2
# Provinsi Kalimantan Selatan      2
# Kepulauan Bangka Belitung        2
# Bengkulu                         2
# Sulawesi Utara                   2
# Jambi                            1
# Kalimantan Tengah                1
# Nusa Tenggara Barat              1
# Sulawesi Tenggara                1
# Kepulauan Riau                   1
# ...

# %% [markdown]
# Asal provinsi peserta terbanyak berasal dari Jawa Barat sebanyak 101 Peserta. Kemudian, Peserta dari Jawa Timur sebanyak 91 peserta

# %% [markdown]
# 4. Perguruan Tinggi

# %%
data['Asal Perguruan Tinggi '].value_counts()
# Out:
# Asal Perguruan Tinggi
# Universitas Diponegoro                          26
# Universitas Brawijaya                           24
# Universitas Airlangga                           18
# Universitas Sebelas Maret                       11
# Universitas Indonesia                            8
#                                                 ..
# Institut Teknologi Perusahaan Listrik Negara     1
# Universitas jakarta                              1
# SMK Swasta Assisi Siantar                        1
# INSTITUT TEKNOLOGI PLN                           1
# Institut Teknologi Telkom Surabaya               1
# Name: count, Length: 225, dtype: int64

# %% [markdown]
# Peserta dengan asal perguruan tinggi terbanyak merupakan mahasiswa Universitas Dipenogoro sebanyak 26 peserta dan Universitas Brawijaya sebanyak 24 peserta

# %% [markdown]
# 5. Departemen yang Diminati

# %% [markdown]
# Unique Metric "Rasio Pria vs Wanita per Departemen"

# %%
data.groupby(['Departemen apa yang kamu inginkan?', 'Jenis Kelamin']).size().unstack(fill_value=0)
# Out:
# Jenis Kelamin                         Laki-laki  Perempuan
# Departemen apa yang kamu inginkan?
# Administration and Finance                   22        101
# Graphic Designer                              2         12
# Human Resource and Development (HRD)         32         87
# Marketing                                    20         21
# Project Officer                              13         30
# Public Relation                              17         41
# Social Media Officer                          9         38
# Video Editor                                  0          1
# WordPress Developer                          10          7
